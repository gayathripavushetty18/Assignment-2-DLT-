-- %%
-- 5. Provide a short notebook showing sample queries and validation that the pipeline produces correct results and lineage is visible.
-- To validate records of bronze[taxi_raw_records] table
select * from gayatri_48.default.taxi_raw_records limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%sql
-- To validate table that flags suspicious rides
select * from gayatri_48.default.flagged_rides;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%sql
-- to validate Silver table with weekly aggregates.
select * from gayatri_48.default.weekly_aggregates;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%sql
-- to validate table showing top-3 highest fare rides
SELECT * FROM gayatri_48.default.top_3
ORDER BY avg_amount DESC, fare_amount DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week</th><th>avg_amount</th><th>avg_distance</th><th>fare_amount</th><th>trip_distance</th><th>zip</th></tr></thead><tbody><tr><td>2016-02-22T00:00:00.000Z</td><td>12.79</td><td>2.973</td><td>60.0</td><td>0.92</td><td>11422</td></tr><tr><td>2016-02-15T00:00:00.000Z</td><td>12.24</td><td>2.894</td><td>60.0</td><td>2.0</td><td>7311</td></tr><tr><td>2016-01-04T00:00:00.000Z</td><td>11.91</td><td>2.865</td><td>95.0</td><td>5.2</td><td>10009</td></tr></tbody></table></div>

-- %%
%python
bronze_count = spark.table("gayatri_48.default.taxi_raw_records").count()
assert bronze_count > 0, "Bronze table is empty!"
print("Validation Passed")
-- Out:
-- Validation Passed
